# %% [markdown]
# # Прогнозирование стоимости автомобиля по характеристикам
#
#
# Образовательная платформа: SkillFactory
#
# Специализация: Data Science
#
# Группа: DST-37 и 38
#
# Юнит 6. Проект 5: "Выбираем автомобиль правильно"
#
#
# ### Задача:
#
#     Создать модель, которая будет предсказывать стоимость автомобиля по его характеристикам для того, чтобы выявлять выгодные предложения (когда желаемая цена продавца ниже предсказанной рыночной цены).
#
# ### Метрика:
#
#     MAPE (Mean Percentage Absolute Error) - средняя абсолютная ошибка в процентах
#
# ### Нужно:
#
#     Составить train датасет - спарсить данные, либо найти готовый
#     Обучить модель
#
# ### Плюс:
#
#     Посмотреть, что можно извлечь из признаков или как еще можно обработать признаки
#     Сгенерировать новые признаки
#     Подгрузить еще больше данных
#     Попробовать подобрать параметры модели
#     Попробовать разные алгоритмы и библиотеки ML
#     Сделать Ансамбль моделей, Blending, Stacking
#
# ### Этапы работы:
#
#     Парсинг с авто.ру - Вадим, Евгений, Артём
#     EDA, Feature Engineering - Артём, Вадим, Евгений
#     Сравнение одиночных моделей - Артём, Вадим
#     Стекинг - Вадим
#
#
# #### В данном ноутбуке мы выполняем подготовку данных.
#
# #### Также в этом проекте мы использовали:
#
# Ноутбук, через который пытались парсить: https://www.kaggle.com/artemskakun/carpriceprediction-autoruparser
#
# Спарсенный датасет мы взяли у этой команды, потому что парсинг занимал очень много времени: https://www.kaggle.com/juliadeinego/data-car-sales
#
# Ноутбук, в котором провели ML: https://www.kaggle.com/artemskakun/sf-dst-car-price-prediction-iron-fingers

# %%
import os
import glob
import pandas as pd
import numpy as np
import json
import csv
from datetime import datetime
from ast import literal_eval

import matplotlib.pyplot as plt
import seaborn as sns


pd.set_option('display.max_columns', None)

RANDOM_SEED = 42

AUTORU_DATA = '../input/data-parsing'
TEST_DATA = '../input/sf-dst-car-price-prediction/'

# %%
# Определение функций
def normalise_doors(row):
    num = row['number_of_doors']
    if pd.isna(num) or num == 0:
        result = 4
        vehicle = row['body_type']
        if vehicle == 'минивэн':
            result = 5
        elif vehicle == 'седан':
            result = 4
        elif vehicle == 'купе':
            result = 2
        return result
    return num

def normalise_model_name(row):
    name = ''
    try:
        d = literal_eval(row['equipment_dict'])
        name = d['model']
    except Exception as e: 
        try:
            val = row['model_name'].split('|')
            if len(val)>1:
                name = val[0]
        except Exception as e2:
            name = row['model_name']
    return name


def normalise_brand_name(row):
    name = ''
    try:
        d = literal_eval(row['equipment_dict'])
        name = d['mark']
    except Exception as e: 
        name = row['brand']
    return name

def normalise_model_date(row):
    val = ''
    try:
        d = literal_eval(row['equipment_dict'])
        val = d['year']
    except Exception as e:
        val = row['production_date']
    finally: #but this work
        try:
            i = int(val)
            return i
        except Exception as e2:
            return 0
        
def normalise_electric_engine(df, row):
    power = row['engine_power']
    mean = df[(df['fuel_type']!='электро') \
                 & (df['engine_power']>=power*0.8) \
                 & (df['engine_power']<=power*1.2)].engine_displacement.mean()
    return int(round(mean, -3))
    
    
rates = {
    '20210416' : 76.9808,
    '20210417' : 75.5535,
    '20210511' : 74.1373,
    '20201021' : 77.7780,
    '20210415' : 75.6826,
    '20201020' : 77.9241,
    '20201019' : 77.9644,
    '20201025' : 76.4667,
    '20201024' : 76.4667,
    '20201026' : 76.4667
}

def price_exchange(row, column, exchange_to='d'):
    rate = rates.get(row['parcing_date'])
    if exchange_to=='d':
        return int(row[column] / rate)
    return int(row[column] * rate)

def remove_whitespace(x):
    try:
        x = "".join(x.split())
    except:
        pass
    return x

def count_words(string, good_words, bad_words):
    i = 0
    try:
        for word in string:
            if type(word) == float:
                continue
            try:
                if word in good_words:
                    i += 1
                elif word in bad_words:
                    i -= 1
            except:
                print(word)
    except:
        pass
    return(i)

# %% [markdown]
# ### Считываем все файлы и объединяем в единый датафрейм

# %%
print('List of data files in directory "data" ->',glob.glob('../input/data-parsing'))

required_columns = ['sell_id','parsing_unixtime','price','bodyType','color','engineDisplacement','enginePower',
                    'fuelType','mileage','productionDate','vehicleTransmission','Владельцы','ПТС','Руль',
                    'Состояние','brand','model_name','equipment_dict','description']

full_df = pd.DataFrame()
for file in glob.glob('../input/data-parsing/*.csv'):
    file_name = file[file.rindex('/')+1:]
    print(file_name)
    df = pd.DataFrame()
    try:
        df = pd.read_csv(file)
    except:
        df = pd.read_csv(file, delimiter=';')
    df = df[required_columns]
    full_df = pd.concat([full_df, df], ignore_index=True)
    
full_df.sample(2)
# Out:
# List of data files in directory "data" -> []
# bmw.csv
# nissan.csv
# infiniti.csv
# honda.csv
# audi.csv
# mitsubishi.csv
# volkswagen.csv
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (1,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# toyota.csv
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# volvo.csv
# lexus.csv
# skoda.csv
# mercedes.csv
#              sell_id parsing_unixtime        price           bodyType   color  \
# 79561   № 1102391439     1620771969.0    435 000 ₽              седан   белый
# 103198  № 1076442800     1618591182.0  2 250 000 ₽  внедорожник 5 дв.  чёрный
#
#        engineDisplacement enginePower fuelType     mileage productionDate  \
# 79561              1.6 л    105 л.с.    Бензин  159 000 км           2014
# 103198             4.7 л    288 л.с.    Бензин  240 000 км           2008
#
#        vehicleTransmission    Владельцы       ПТС   Руль           Состояние  \
# 79561         механическая  2 владельца  Оригинал  Левый  Не требует ремонта
# 103198      автоматическая  2 владельца  Оригинал  Левый  Не требует ремонта
#
#              brand    model_name  \
# 79561   Volkswagen          Polo
# 103198      Toyota  Land Cruiser
#
#                                            equipment_dict  \
# 79561   {'asciiCat': 'cars', 'category': 'cars', 'engi...
# 103198  {'asciiCat': 'cars', 'category': 'cars', 'engi...
#
#                                               description
# 79561                                       Торг у капота
# 103198  Машина на отличном ходу, все работает исправно...

# %% [markdown]
# ### Удалим дубликаты и пустые строки из спарсенных данных

# %%
full_df = full_df.drop_duplicates(subset=['sell_id'])
full_df = full_df.dropna(how='all')
len(full_df)
# Out:
# 101304

# %% [markdown]
# ### Оставляем только необходимые признаки

# %%
# создаем список с новым названием колонок
new_columns = ['sell_id','parsing_unixtime','price','body_type','color','engine_displacement','engine_power',
               'fuel_type','mileage','production_date','vehicle_transmission','owners','vehicle_pasport',
               'wheel','condition','brand','model_name','equipment_dict','description']
        
# оставляем в датасете выбранные колонки
full_df = full_df[required_columns]

# переименуем колонки
full_df.columns = new_columns

full_df.sample(2)
# Out:
#             sell_id parsing_unixtime      price          body_type   color  \
# 59731  № 1103139489     1618583409.0  800 000 ₽  внедорожник 5 дв.  чёрный
# 21596  № 1102851906     1618643332.0  149 000 ₽              седан   синий
#
#       engine_displacement engine_power fuel_type     mileage production_date  \
# 59731              3.2 л     160 л.с.     Дизель  303 000 км            2005
# 21596              2.5 л     210 л.с.     Бензин  250 000 км            2001
#
#       vehicle_transmission       owners vehicle_pasport   wheel  \
# 59731         механическая  2 владельца        Оригинал   Левый
# 21596       автоматическая  3 или более        Дубликат  Правый
#
#                 condition       brand model_name  \
# 59731  Не требует ремонта  Mitsubishi     Pajero
# 21596  Не требует ремонта      Nissan     Cefiro
#
#                                           equipment_dict  \
# 59731  {'asciiCat': 'cars', 'category': 'cars', 'engi...
# 21596  {'asciiCat': 'cars', 'category': 'cars', 'engi...
#
#                                              description
# 59731  Продаю отличный автомобиль! Я второй хозяин. С...
# 21596  Легенда бизнес класса тех времен.Чистая япошка...

# %% [markdown]
# ### Проведём первичную обработку датасета

# %%
def preprocessing_autoru_df(df):
    df.drop(['sell_id'], axis=1, inplace=True)
    # model date
    df['production_date'] = df['production_date'].fillna(0)
    df['model_date'] = df.apply(lambda row : normalise_model_date(row), axis=1)
    df['model_name'] = df.apply(lambda row : normalise_model_name(row), axis=1)
    df['brand'] = df.apply(lambda row : normalise_brand_name(row), axis=1)
    df.drop(df[(df['model_name'].isna()) & (full_df['brand'].isna())].index, inplace=True)
    
    df.drop('equipment_dict', axis=1, inplace=True)

    df['mileage'] = df['mileage'].fillna('0')
    df['mileage'] = df['mileage'].apply(remove_whitespace)
    df['mileage'] = df['mileage'].str.extract('(\d+)', expand=True)
    df['mileage'] = df['mileage'].fillna(0).astype(int)

    
preprocessing_autoru_df(full_df)
full_df.head(2)
# Out:
#   parsing_unixtime        price body_type      color engine_displacement  \
# 0     1618565279.0     95 000 ₽     седан  пурпурный              1.8 л
# 1     1618565279.0  7 990 000 ₽      купе      серый              1.5 л
#
#   engine_power fuel_type  mileage production_date vehicle_transmission  \
# 0    113 л.с.     Бензин   385000            1992         механическая
# 1    231 л.с.     Гибрид    17979            2018       автоматическая
#
#         owners vehicle_pasport  wheel           condition brand model_name  \
# 0  3 или более        Дубликат  Левый  Не требует ремонта   BMW        3ER
# 1  3 или более        Оригинал  Левый  Не требует ремонта   BMW         I8
#
#                                          description  model_date
# 0  В хорошем состоянии. Двигатель в отличном сост...        1992
# 1  В продаже автомобиль от компании АО ABTODOM, о...        2018

# %% [markdown]
# ### Загружаем тестовый датасет

# %%
test = pd.read_csv('../input/sf-dst-car-price-prediction/test.csv')
test.sample(2)
# Out:
#             bodyType   brand  \
# 1284         лифтбек   SKODA
# 32728  хэтчбек 5 дв.  NISSAN
#
#                                                  car_url        color  \
# 1284   https://auto.ru/cars/used/sale/skoda/octavia/1...      зелёный
# 32728  https://auto.ru/cars/used/sale/nissan/march/10...  серебристый
#
#       complectation_dict                                        description  \
# 1284                 NaN  Всем добрый день!\nПродаю свой любимый авто. \...
# 32728                NaN  Отличный автомобиль. Ездила жена в пределах ра...
#
#       engineDisplacement enginePower  \
# 1284             1.8 LTR     150 N12
# 32728            1.2 LTR      90 N12
#
#                                           equipment_dict fuelType  \
# 1284   {"engine-proof":true,"tinted-glass":true,"esp"...   бензин
# 32728  {"tinted-glass":true,"airbag-driver":true,"aux...   бензин
#
#                                                    image  mileage  modelDate  \
# 1284   https://avatars.mds.yandex.net/get-autoru-vos/...   301329       1996
# 32728  https://autoru.naydex.net/1xsMU7627/eea2057RFg...   122000       2002
#
#                                               model_info model_name  \
# 1284   {"code":"OCTAVIA","name":"Octavia","ru_name":"...    OCTAVIA
# 32728  {"code":"MARCH","name":"March","ru_name":"Марч...      MARCH
#
#                     name  numberOfDoors  parsing_unixtime priceCurrency  \
# 1284   1.8 AT (150 л.с.)              5        1603231116           RUB
# 32728   1.2 AT (90 л.с.)              5        1603605574           RUB
#
#        productionDate     sell_id  \
# 1284             2000  1101127476
# 32728            2004  1093060658
#
#                                                super_gen  \
# 1284   {"id":"20501027","displacement":1781,"engine_t...
# 32728  {"id":"8299524","displacement":1240,"engine_ty...
#
#                   vehicleConfiguration vehicleTransmission    vendor  \
# 1284            LIFTBACK AUTOMATIC 1.8      автоматическая  EUROPEAN
# 32728  HATCHBACK_5_DOORS AUTOMATIC 1.2      автоматическая  JAPANESE
#
#          Владельцы           Владение       ПТС    Привод    Руль  \
# 1284   3 или более    1 год и 1 месяц  Оригинал  передний   Левый
# 32728  3 или более  1 год и 7 месяцев  Оригинал  передний  Правый
#
#                 Состояние     Таможня
# 1284   Не требует ремонта  Растаможен
# 32728  Не требует ремонта  Растаможен

# %%
# выберем интересующие нас признаки
columns = ['bodyType', 'brand', 'color', 'engineDisplacement', 'enginePower',
           'fuelType', 'mileage', 'modelDate', 'model_name', 'numberOfDoors', 'parsing_unixtime',
           'productionDate', 'vehicleTransmission', 'Владельцы', 'ПТС', 'Руль', 'Состояние', 'description']

df_test = test[columns]

# создаем список с новым названием признаков
new_columns = ['body_type', 'brand', 'color', 'engine_displacement', 'engine_power',
               'fuel_type', 'mileage', 'model_date', 'model_name', 'number_of_doors', 'parsing_unixtime',
               'production_date', 'vehicle_transmission', 'owners', 'vehicle_pasport',
               'wheel', 'condition', 'description']

df_test.columns = new_columns

df_test.sample(2)
# Out:
#      body_type  brand   color engine_displacement engine_power fuel_type  \
# 355    лифтбек  SKODA   серый             1.8 LTR      152 N12    бензин
# 7888     седан    BMW  чёрный             3.0 LTR      249 N12    дизель
#
#       mileage  model_date model_name  number_of_doors  parsing_unixtime  \
# 355    141532        2008    OCTAVIA                5        1603227649
# 7888     7340        2019        7ER                4        1603108977
#
#       production_date vehicle_transmission       owners vehicle_pasport  \
# 355              2009     роботизированная  2 владельца        Оригинал
# 7888             2019       автоматическая   1 владелец        Оригинал
#
#       wheel           condition  \
# 355   Левый  Не требует ремонта
# 7888  Левый  Не требует ремонта
#
#                                             description
# 355   ,\nБезопасная покупка в АСЦ/ЧЕСТНО –легко! \nС...
# 7888  «Inchcape Certified-  Первый международный офи...

# %% [markdown]
# ### Объединим оба датасета и проведем дальнейшую обработку одновременно

# %%
full_df['test'] = 0
df_test['test'] = 1
df_test['price'] = 0
full_df = pd.concat([full_df, df_test], ignore_index=True)
# Out:
# <ipython-input-10-029da23d6a0b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['test'] = 1
# <ipython-input-10-029da23d6a0b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['price'] = 0

# %% [markdown]
# ### Проведем дальнейшую предобработку для объединенного датафрейма

# %%
# найдём и удалим строку с неверными значениями
a = full_df[full_df['parsing_unixtime'] == 'https://avatars.mds.yandex.net/get-autoru-vos/2090686/56351fff854ba117076587162cfc6805/1200x900n'].index
full_df = full_df.drop(a, axis=0)

def preprocessing_full_df(df):
    # убираем пустые строки
    df.dropna(axis=1, how='all', inplace=True)
    
    # обрабатываем признак engine_power 
    df['engine_power'] = df['engine_power'].astype(str).str.extract('(\d+)', expand=True)\
        .fillna(0).astype(int)
    
    # обрабатываем признак engine_displacement
    df['engine_displacement'] = ((df['engine_displacement']).astype(str)\
        .str.extract('([0-9.]+)', expand=True).astype(float)\
        .fillna(0)*1000).astype(int)
    df['engine_displacement'] = df.apply(lambda row : normalise_electric_engine(df, row) \
        if (row.fuel_type=='электро') | (row.engine_displacement==0) else row.engine_displacement , axis=1)
    
    # обрабатываем признак number_of_doors
    df['number_of_doors'] = df.apply(lambda row : normalise_doors(row), axis=1).astype(int).apply(str)

    # обрабатываем признак body_type
    df['body_type'] = df['body_type'].fillna('седан')\
        .astype(str).apply(lambda x: x[:x.find(" ")] if x.find(" ") > 0 else x)
    
    # обрабатываем признак fuel_type
    df['fuel_type'] = df['fuel_type'].fillna('бензин').str.strip()\
        .replace({"бензин, газобаллонное оборудование": "бго", 
                  "газ, газобаллонное оборудование": "газ",
                  "дизель, газобаллонное оборудование": "дизель",
                  "гибрид, газобаллонное оборудование": "гибрид"}, inplace=True)
    
    # обрабатываем признак owners
    df['owners'] = df['owners'].astype(str)\
        .str.extract('(\d+)', expand=True)\
        .fillna('1').astype(int)

    # обрабатываем признак price
    df['price'] = df['price'].apply(remove_whitespace)\
        .str.extract('(\d+)', expand=True)\
        .fillna(0).astype(int)

    # обрабатываем признак vehicle_pasport
    df['vehicle_pasport'] = df['vehicle_pasport'].fillna('Оригинал')

    # обрабатываем признак production_date
    df['production_date'] = df['production_date'].fillna(df['production_date'].median()).astype(int)
    df['model_date'] = df['model_date'].fillna(value=df['production_date']).astype(int)
    
    # переводим признаки в нижний регистр
    for col in ['body_type','color','fuel_type','vehicle_transmission','vehicle_pasport',
                'wheel','brand']:
        df[col] = df[col].astype(str).str.lower()
    
    # переводим model_name в верхний регистр
    df['model_name'] = df['model_name'].astype(str).str.upper()

    # удаляем лишние признаки
    df.drop(df[df['condition'] == 'Битый / не на ходу'].index, inplace=True)
    df.drop('parsing_unixtime', axis=1, inplace=True)
    df.drop('production_date', axis=1, inplace=True)

preprocessing_full_df(full_df)
full_df.sample(2)
# Out:
#          price    body_type   color  engine_displacement  engine_power  \
# 70141  1495000  внедорожник  чёрный                 2000           146
# 52561   570000   компактвэн  чёрный                 1200           105
#
#       fuel_type  mileage vehicle_transmission  owners vehicle_pasport  wheel  \
# 70141      none    83000             вариатор       2        оригинал  левый
# 52561      none   191000         механическая       3        оригинал  левый
#
#                 condition       brand model_name  \
# 70141  Не требует ремонта      toyota      RAV_4
# 52561  Не требует ремонта  volkswagen      CADDY
#
#                                              description  model_date  test  \
# 70141  Японская сборка. Дата первой продажи из салона...        2013     0
# 52561  Volkswagen Caddy в хорошем техническом состоян...        2012     0
#
#       number_of_doors
# 70141               4
# 52561               4

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 135986 entries, 0 to 135988
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   price                 135986 non-null  int64
#  1   body_type             135986 non-null  object
#  2   color                 135986 non-null  object
#  3   engine_displacement   135986 non-null  int64
#  4   engine_power          135986 non-null  int64
#  5   fuel_type             135986 non-null  object
#  6   mileage               135986 non-null  int64
#  7   vehicle_transmission  135986 non-null  object
#  8   owners                135986 non-null  int64
#  9   vehicle_pasport       135986 non-null  object
#  10  wheel                 135986 non-null  object
#  11  condition             135986 non-null  object
#  12  brand                 135986 non-null  object
#  13  model_name            135986 non-null  object
#  14  description           135433 non-null  object
#  15  model_date            135986 non-null  int64
#  16  test                  135986 non-null  int64
#  17  number_of_doors       135986 non-null  object
# dtypes: int64(7), object(11)
# memory usage: 19.7+ MB

# %% [markdown]
# ### Обработаем текстовое поле description

# %% [markdown]
# Попытаемся получить дополнительный признак о наличии положительных и отрицательных слов в тексте объявления

# %%
words_dct = {}
for description in full_df['description']:
    if type(description) == float:
        continue
    description = description.lower()
    description = description.replace('!', '').replace('.', '').replace(',', '')
    description = description.split(' ')
    for word in description:
        if word in words_dct:
            words_dct[word] += 1
        else:
            words_dct[word] = 1
words_dct
# Out:
# {'в': 363219,
#  'хорошем': 18042,
#  'состоянии': 45292,
#  'двигатель': 13122,
#  'отличном': 22943,
#  'состояние': 17292,
#  'сухой': 237,
#  'новая': 8267,
#  'помпа': 821,
#  'грм': 3455,
#  'передние': 19011,
#  'рычаги': 1153,
#  'тормозные': 4667,
#  'диски': 12578,
#  'резина': 17587,
#  'зима': 6655,
#  'кожаный': 7618,
#  'салон': 23583,
#  'музыка': 3922,
#  'стеклоподъёмники': 252,
#  'машина': 29492,
#  'не': 154626,
#  'гнилая': 314,
#  'стаканы': 87,
#  'родные': 2618,
#  'варились': 9,
#  'и': 300956,
#  'красилась': 463,
#  'движок': 526,
#  'родной': 10725,
#  'машины': 4490,
#  'полностью': 13753,
#  'на': 212130,
#  'ходу': 3399,
#  'вложений': 11062,
#  'требует': 10379,
#  'юридический': 55,
#  'все': 67906,
#  'чист': 699,
#  'торг': 24975,
#  'обмен': 19293,
#  'автокредит': 2250,
#  'наша': 207,
#  'компания': 1370,
#  'amirravto': 20,
#  'уже': 4850,
#  'более': 23493,
#  '5': 7639,
#  'лет': 12165,
#  'успешно': 680,
#  'работает': 13086,
#  'автомобильном': 589,
#  'рынке': 2092,
#  'за': 33120,
#  'это': 11592,
#  'время': 12351,
#  'динамично': 23,
#  'развивается': 10,
#  'открывает': 32,
#  'новые': 7045,
#  'направления': 39,
#  'расширяя': 10,
#  'спектр': 1589,
#  'услуг': 2763,
#  'профессионально': 41,
#  'ведет': 88,
#  'деятельность': 48,
#  'по': 140825,
#  'выкупу': 588,
#  'автомобилей': 8,
#  'с': 200107,
#  'пробегом': 34624,
#  'у': 50125,
#  'физических': 77,
#  'юридических': 408,
#  'лиц': 219,
#  'набережных': 17,
#  'челнах': 15,
#  'а': 12022,
#  'так': 14207,
#  'же': 9424,
#  'других': 1227,
#  'городах': 37,
#  'районах': 8,
#  'всей': 8,
#  'республики': 94,
#  'татарстан': 24,
#  'преимущества': 1391,
#  'нашего': 1211,
#  'салона:': 1526,
#  '✅': 3013,
#  'выкупим': 402,
#  'ваш': 20283,
#  'автомобиль': 85164,
#  'выгодных': 3240,
#  'условиях': 3354,
#  'возможна': 3732,
#  'покупка': 5619,
#  'кредит': 25920,
#  'тест': 568,
#  '-': 64757,
#  'драйв': 8,
#  'любого': 1385,
#  'автомобиля': 48788,
#  'от': 52495,
#  '88%': 127,
#  'без': 48150,
#  'первоначального': 6158,
#  'взноса': 3128,
#  'каско': 11665,
#  '30': 5750,
#  'банков-партнеров': 680,
#  'выгодный': 8,
#  'системе': 3518,
#  'trade-in': 5102,
#  'оценка': 3551,
#  'стоимости': 2891,
#  'вашего': 20977,
#  'телефону': 14274,
#  'гарантируем': 2610,
#  'безопасность': 2273,
#  'юридическую': 4802,
#  'чистоту': 1842,
#  'диагностика': 4902,
#  'любом': 982,
#  'сервисном': 182,
#  'центре': 3481,
#  'вашему': 1185,
#  'желанию': 503,
#  'осмотр': 5986,
#  'автоцентр': 264,
#  'гнабережные': 20,
#  'челны': 96,
#  'казанский': 8,
#  'проспект': 422,
#  '226ст2': 10,
#  '(': 7238,
#  'первая': 482,
#  'дорога': 122,
#  'доезжая': 11,
#  'до': 48452,
#  'гараж': 153,
#  '2000': 437,
#  'напротив': 47,
#  'бакинский': 8,
#  'дворик)': 8,
#  'продаже': 8639,
#  'компании': 2677,
#  'ао': 1138,
#  'abtodom': 670,
#  'официальный': 6852,
#  'дилер': 6590,
#  '(bmw': 203,
#  'mini': 528,
#  'bmw': 8607,
#  'i': 440,
#  'motorrad)цвет': 19,
#  'c22': 1,
#  'sophisto-grau': 2,
#  'brillant/frozen-greyобивка': 1,
#  'сидений': 21711,
#  'ngha': 1,
#  'недвоёная': 1,
#  'кожа': 4149,
#  'spheric': 1,
#  'перфорир/amido0609\tсистема': 1,
#  'навигации': 697,
#  'professional01ag\tувеличенный': 1,
#  'топливный': 1050,
#  'бак027k\t20"': 1,
#  'л/с': 508,
#  'дмногоспдиск': 1,
#  '516': 2,
#  'двухцветный02bq\tтормозной': 1,
#  'суппорт': 50,
#  'окрашенный02vb\tиндикация': 1,
#  'давления': 5099,
#  'шинах02vc\tнабор': 1,
#  'для': 43681,
#  'ремонта': 2393,
#  'шин0322\tкомфортный': 1,
#  'доступ03cm\tкожух': 1,
#  'двигателя': 7970,
#  'кожа03ds\tbmw': 1,
#  'ключ': 1217,
#  'дисплеем0423\tножные': 1,
#  'коврики0428\tзнак': 15,
#  'аварийной': 1174,
#  'остановки': 817,
#  'аптечка0430\tвнутр/нарзеркс': 11,
#  'затемнением0458\tрегулировка': 1,
#  'сиденья': 15649,
#  'пд': 226,
#  'э/приводом0493\tпакет': 1,
#  'мест': 1728,
#  'хранения0494\tсистема': 10,
#  'обогрсиденводителя/передпасс04aa\tпотолок': 1,
#  'антрацит04cq\tдекоративная': 1,
#  'планка': 62,
#  'салона': 8425,
#  'drycarbon04fg\tремень': 1,
#  'безопасности': 18456,
#  'синий04u1\tкерамическая': 1,
#  'вставка': 86,
#  'дорганов': 42,
#  'управл04u9\tакустическая': 1,
#  'защита': 6153,
#  'пешеходов0508\tсигнализация': 2,
#  'аварсближенпри': 395,
#  'парк(pdc)0563\tпакет': 1,
#  'светотехники05a4\tс/д': 1,
#  'фары': 8122,
#  'расширенным': 75,
#  'объемом': 186,
#  'функций05as\tdriving': 1,
#  'assistant0610\tдисплей': 1,
#  'лобовом': 1744,
#  'стекле0674\tсистема': 1,
#  'hifi': 147,
#  'harman': 615,
#  'kardon06ae\tteleservices06af\tэкстренный': 1,
#  'вызов': 321,
#  'законодатальству06ak\tconnected': 7,
#  'drive': 822,
#  'services06am\treal-time': 10,
#  'traffic': 315,
#  'information06an\tconcierge': 9,
#  'services06ap\tremote': 9,
#  'services06cp\tподготовка': 3,
#  'apple': 1096,
#  'carplay06ns\tкомф': 1,
#  'телеф': 66,
#  'связь': 657,
#  'пом': 81,
#  'смартфона06ud\tязыковая': 2,
#  'версия': 869,
#  'русский07cg\tbmw': 1,
#  'repair': 336,
#  'inclusive07d7\tbmw': 1,
#  'service': 113,
#  'inklusive07s9\tconnected': 1,
#  'services': 185,
#  'paket0891\tбортовая': 1,
#  'документация': 621,
#  'русский08bl\tзарядный': 1,
#  'провод': 61,
#  'отсутствует08lr\tуправление': 1,
#  'странам': 450,
#  'россия': 693,
#  '10323все': 5,
#  'наши': 3625,
#  'автомобили': 29766,
#  'площадке': 1049,
#  'мкад': 2053,
#  '51': 254,
#  'вы': 14569,
#  'можете': 9513,
#  'посмотреть': 1297,
#  'нажав': 413,
#  'ссылку': 505,
#  '"продавец': 387,
#  'abtodom"': 387,
#  'контактной': 389,
#  'информации': 699,
#  '2': 24613,
#  '': 325211,
#  'gran': 25,
#  'tourer': 26,
#  '2016': 1854,
#  'года-': 131,
#  'птс': 21830,
#  'оригинал-': 229,
#  'комплекта': 16448,
#  'заводских': 151,
#  'ключей-': 162,
#  'технически': 3382,
#  'идеальном': 9012,
#  'состоянии-': 380,
#  'кузов': 8023,
#  'дтп': 16939,
#  'весть': 2,
#  'заводском': 1606,
#  'лакокрасочном': 147,
#  'покрытии-': 5,
#  'чистый': 5133,
#  'ухоженный': 3405,
#  'вытертый': 4,
#  'прокуренный-': 7,
#  'динамика': 619,
#  'высоте': 1155,
#  'минимальный': 2922,
#  'расход': 4358,
#  'топлива': 1599,
#  'городу': 1476,
#  '6л': 52,
#  '100': 6772,
#  'км': 13176,
#  'трассе': 2106,
#  'того': 1220,
#  'меньше-': 1,
#  'хорошая': 3917,
#  'комплектация-': 127,
#  'обслужен': 3720,
#  'никаких': 5666,
#  'дополнительных': 967,
#  'вложений-': 25,
#  'прозрачная': 574,
#  'история-': 150,
#  'реальному': 2488,
#  'покупателю': 3313,
#  'хороший': 3160,
#  'вопросы': 12029,
#  'телефону-': 5,
#  'карпрайс': 81,
#  'рольф': 8524,
#  'major': 164,
#  'прочие': 716,
#  'автосалоны': 1801,
#  'огромная': 214,
#  'просьба': 5212,
#  'беспокоить': 6266,
#  'https://wwwdrive2ru/r/bmw/z3/466000241837998368/': 1,
#  'матоваяпросто': 1,
#  'помыта': 7,
#  'мойкойтак': 1,
#  'как': 16422,
#  'была': 5898,
#  'грязнаядурачки': 1,
#  '400': 1775,
#  'заберу': 139,
#  'идут': 191,
#  'напродам': 1,
#  'отличный': 4233,
#  'дизельный': 465,
#  'полно-приводный': 2,
#  'кроссовер': 499,
#  'автоматеbmw': 1,
#  'x3': 222,
#  'e83': 8,
#  'рестайлинг': 1041,
#  '2007': 774,
#  'год': 8347,
#  '20': 7748,
#  'дизель': 1101,
#  '177лсхорошая': 1,
#  'комплектациябежевый': 1,
#  'салонклимат': 11,
#  'контролькруиз': 93,
#  'контрольнавигацияобогрев': 1,
#  'сиденийэлектро': 52,
#  'зеркала': 4043,
#  'обогревомсистемы': 1,
#  'курсовой': 6940,
#  'устойчивостипомощь': 2,
#  'подъема': 52,
#  'гору': 192,
#  'спуск': 5,
#  'горымультирульполный': 1,
#  'набор': 591,
#  'ключейгромкая': 1,
#  'связьавтомобиль': 2,
#  'нуждается': 128,
#  'ремонте': 138,
#  'двигателяпровернуло': 1,
#  'вкладыш': 70,
#  '4-го': 61,
#  'цилиндрадвигатель': 1,
#  'прошит': 163,
#  'stage': 230,
#  '1(программно': 1,
#  'отшит': 11,
#  'удален': 153,
#  'егр)клапанную': 1,
#  'крышку': 187,
#  'скинулимасло': 1,
#  'слилиубедились(сработали': 1,
#  'шторки': 4163,
#  'боковыеесть': 1,
#  'небольшая': 781,
#  'вмятина': 622,
#  'передней': 1320,
#  'правой': 805,
#  'двери': 3382,
#  '(можно': 153,
#  'выкатать)фронтальная': 1,
#  'вся': 5642,
#  'местесъехали': 1,
#  'дорогидтп': 1,
#  'оформлялосьгаи': 1,
#  'вызывалимашину': 1,
#  'отрабатывали-': 1,
#  'краска': 921,
#  'везде': 621,
#  'родная-': 3,
#  'коробка': 10133,
#  'отлично-': 9,
#  'турбина': 907,
#  'нареканийосмотр': 2,
#  'автостоянка': 1,
#  'проезд': 538,
#  'автомобилистов': 4,
#  'установлен': 3598,
#  'новый': 11362,
#  'мотор': 5098,
#  'стойки': 2709,
#  'турбины': 507,
#  'один': 11499,
#  'подкрас': 30,
#  '20см': 9,
#  'реально': 985,
#  'живая': 432,
#  'большим': 511,
#  'потенциалом': 9,
#  'подробности': 3257,
#  'шару': 2,
#  'продаётся': 2638,
#  'авто': 41860,
#  'полный': 13140,
#  'заводской': 2376,
#  'стоккуплена': 1,
#  'москве': 2834,
#  '2017гна': 4,
#  'гарантии': 5210,
#  'официального': 18625,
#  'дилера': 16695,
#  '21062021': 2,
#  'возможностью': 1284,
#  'платного': 3,
#  'продления': 44,
#  '21062022полностью': 1,
#  'пленке': 805,
#  'suntek': 100,
#  'включая': 2383,
#  'карбоновые': 131,
#  'деталицвет': 1,
#  'individual': 488,
#  'java': 2,
#  'green': 26,
#  'полосками': 4,
#  'motorsport': 25,
#  'заводасвоевременное': 1,
#  'обслуживание': 13321,
#  'то': 24271,
#  'каждые': 6607,
#  '4000-5000': 2,
#  'участвовала': 3829,
#  'гаражное': 1364,
#  'хранениеавто': 4,
#  'находится': 3204,
#  'алматы': 3,
#  'казахстан': 10,
#  'помогу': 89,
#  'отправкой': 13,
#  'любой': 6125,
#  'регионпросьба': 1,
#  'звонить': 4533,
#  'реальным': 654,
#  'покупателям': 301,
#  'спасибо': 420,
#  'обслуженный': 627,
#  'x': 423,
#  'самой': 463,
#  'максимальной': 1458,
#  'комплектации:': 328,
#  'круиз': 3348,
#  'контроль': 6288,
#  'электропривод': 13184,
#  'рулялимитер': 1,
#  'бесключевой': 2278,
#  'доступ': 3308,
#  'доводчики': 1417,
#  'дверейэлектросиденья': 1,
#  'ломающимися': 69,
#  'спинками': 75,
#  'памятью': 4635,
#  'панорамная': 2196,
#  'крыша': 2262,
#  'проекция': 769,
#  'подогрев': 19442,
#  'вентиляция': 2381,
#  'всех': 10425,
#  'парктроники': 2282,
#  'камера': 10891,
#  'заднего': 21504,
#  'вида': 7401,
#  'камеры': 1658,
#  '360': 766,
#  'боковые': 6785,
#  'помощь': 2481,
#  'при': 46654,
#  'спуске': 630,
#  'подъеме': 414,
#  'руля': 8165,
#  'блютуз': 532,
#  'тв': 284,
#  'сд': 48,
#  'мр3': 91,
#  'навигация': 1632,
#  'телефон': 825,
#  'аукс': 99,
#  'юсб': 36,
#  'обогрев': 20052,
#  'переднего': 3618,
#  'стекла': 6398,
#  'электростеклоподъемникифорсунки': 1,
#  '12': 2390,
#  'ревизии': 86,
#  'свечи': 2315,
#  'колодки': 4945,
#  'зимняя': 7506,
#  'летняя': 5581,
#  'комплекте': 3262,
#  'есть': 28626,
#  'косметические': 423,
#  'окрасы': 301,
#  'из-за': 1314,
#  'пескоструй': 31,
#  'учавствовал': 101,
#  'страховкам': 11,
#  'проводился': 47,
#  'любые': 9720,
#  'проверки': 8849,
#  'счёт': 2006,
#  'сел': 3676,
#  'поехал': 3310,
#  'летит': 12,
#  'положенно': 19,
#  'капота': 8675,
#  'возможен': 7376,
#  'обмен(': 1,
#  'участки': 65,
#  'дома': 804,
#  'металлоконструкции': 6,
#  'предлагать)': 20,
#  '-добрый': 1,
#  'день': 12378,
#  'выставляю': 35,
#  'продажу': 752,
#  'личный': 1058,
#  'x5-состояние': 1,
#  'близкое': 147,
#  'к': 12084,
#  'идеальному': 194,
#  'делать': 1216,
#  'ничего': 3716,
#  'нужно': 3723,
#  'только': 21098,
#  'после': 6661,
#  'ухожена': 268,
#  'обслужена': 2657,
#  'ниже': 559,
#  'буду': 1734,
#  'описывать': 108,
#  'подробно': 1296,
#  'чтобы': 1814,
#  'поняли': 21,
#  'вам': 10468,
#  'может': 2567,
#  'повезти)-комплектация:сиденья': 1,
#  'повышенной': 521,
#  'комфортности': 256,
#  'подкачкой': 87,
#  'дверей': 3406,
#  '3': 10360,
#  'парктроник': 6546,
#  'подсветка': 2089,
#  'дверных': 251,
#  'ручек': 294,
#  'кнопка': 1325,
#  'багажника': 3814,
#  'shadow': 422,
#  'line': 793,
#  'bluetooth/aux/usb/dvd-так': 1,
#  'стоят': 1290,
#  'разноширокие': 540,
#  'колеса': 2749,
#  '469-м': 1,
#  'стиль': 529,
#  'японской': 614,
#  'резине': 1432,
#  'nittoавтомобиль': 1,
#  'покрыт': 800,
#  'жидким': 259,
#  'стеклом': 354,
#  'живую': 245,
#  'выглядит': 527,
#  'еще': 2035,
#  'лучше': 1734,
#  'чем': 4239,
#  'фото-техническая': 1,
#  'часть': 2734,
#  'нареканий': 5746,
#  'вопросов': 566,
#  'холодную': 101,
#  'горячую': 19,
#  'нагрузке': 11,
#  'провалов': 15,
#  'шумов': 228,
#  'воющих': 1,
#  'свистящих': 1,
#  'роликов': 221,
#  'ремней': 649,
#  'прочего': 337,
#  'режиме': 837,
#  'бьет': 31,
#  'пинает': 689,
#  'выбивает': 23,
#  'подвеска': 4970,
#  'сбитая': 16,
#  'стучит': 1131,
#  'ходовая': 3282,
#  'держит': 375,
#  'машину': 8535,
#  'повороте': 119,
#  'электрика': 689,
#  'исправна': 595,
#  'гудит': 89,
#  'затертый': 235,
#  'засиженный': 1,
#  'никто': 568,
#  'реставрировал': 4,
#  'прекрасном': 992,
#  'химчистки': 147,
#  'консервациилобовое': 1,
#  'стекло': 3001,
#  '-оригинал': 13,
#  '-хочу': 2,
#  'подчеркнуть': 7,
#  'что': 15372,
#  'продаю': 13974,
#  'избавляюсь': 852,
#  'вынуждают': 64,
#  'финансовые': 83,
#  'обязательства': 10,
#  'адекватный': 268,
#  'диагностики': 2580,
#  'приветствуются': 690,
#  'стыдно': 1871,
#  'салоны': 2425,
#  'перекупщики': 452,
#  'помощники': 296,
#  'проходим': 47,
#  'мимо': 1383,
#  'вариант': 1145,
#  'езжу': 3294,
#  'машине': 6480,
#  'каждый': 11265,
#  'самостоятельно': 297,
#  'новым': 1748,
#  'владельцем': 1035,
#  'готов': 4333,
#  'вместе': 1236,
#  'приехать': 311,
#  'переоформление': 511,
#  'гибдд': 3802,
#  'оставшиеся': 43,
#  'отвечу': 2515,
#  'звоните': 7788,
#  'стесняйтесь': 56,
#  'p7aca': 2,
#  'sport': 1531,
#  'lines161a': 1,
#  'норма': 200,
#  'токсичности': 226,
#  'ог': 511,
#  'eu5s1caa': 3,
#  'выбор': 3775,
#  'а/м': 5853,
#  'имеющих': 200,
#  'отношение': 473,
#  'cops205a': 2,
#  'автоматическая': 1855,
#  'передачs248a': 2,
#  'система': 44687,
#  'обогрева': 770,
#  'рулевого': 2732,
#  'колесаs258a': 5,
#  'шины': 3646,
#  'допускающие': 409,
#  'движ': 21,
#  'аварийном': 467,
#  'режимеs2a5a': 1,
#  'л/c': 136,
#  'диск': 957,
#  'со': 7275,
#  'сдвоенными': 138,
#  'спиц': 149,
#  'диз': 21,
#  '397s2paa': 1,
#  'фиксатор': 129,
#  'колесного': 238,
#  'болтаs316a': 1,
#  'автоматический': 1065,
#  'привод': 4384,
#  'багажной': 515,
#  'двериs423a': 1,
#  'ножные': 213,
#  'коврики': 2239,
#  'velourss428a': 16,
#  'знак': 550,
#  'аптечкаs441a': 5,
#  'комплект': 21624,
#  'курящихs465a': 3,
#  'сист': 165,
#  'люком': 480,
#  'д': 1535,
#  'перевозки': 218,
#  'длинном': 7,
#  'предмs481a': 2,
#  'спортивное': 597,
#  'сиденьеs493a': 2,
#  'пакет': 8885,
#  'храненияs494a': 11,
#  'обогр': 10,
#  'сиден': 14,
#  'водителя/перед': 9,
#  'пассs4aea': 1,
#  'armauflage': 4,
#  'vorn': 23,
#  'verschiebbars4lva': 1,
#  'черный': 1870,
#  'глянцевый': 55,
#  'акцент': 82,
#  'korall-': 1,
#  'rots502a': 1,
#  'омывателей': 372,
#  'фарs508a': 23,
#  'сигнализация': 10765,
#  'авар': 12,
#  'сближен': 9,
#  'парк(pdc)s521a': 9,
#  'regensensors522a': 8,
#  'ксеноновая': 112,
#  'фараs534a': 10,
#  'кондиционированияs548a': 9,
#  'спидометрs563a': 9,
#  'светотехникиs6aca': 1,
#  'интеллектуальный': 98,
#  'экстренный': 346,
#  'вызовs6aea': 8,
#  'teleservicess6nha': 3,
#  'устр-': 1,
#  'во': 3183,
#  'громкой': 284,
#  'связи': 4674,
#  'интерфейсом': 95,
#  'usbs6uda': 2,
#  'языковая': 339,
#  'русскийs6waa': 2,
#  'комб': 46,
#  'приборов': 981,
#  'расширенными': 243,
#  'функциямиs6waa': 1,
#  'функциямиs701a': 2,
#  'код': 1391,
#  'dvds7caa': 3,
#  'inclusives842a': 4,
#  'исполнение': 612,
#  'стран': 1407,
#  'холодным': 1057,
#  'климатомs891a': 7,
#  'бортовая': 275,
#  'русскийs8lra': 5,
#  'управление': 2086,
#  '10323авто': 1,
#  'технике': 907,
#  'новых': 1051,
#  'оригинальных': 3057,
#  'дискахстоит': 7,
#  'дорогая': 773,
#  'а/з': 480,
#  'starline': 1004,
#  's96': 44,
#  'факту': 4409,
#  'владельца': 3660,
#  'был': 5487,
#  'перевес': 139,
#  'номеров': 834,
#  'страна': 150,
#  'сборки-': 1,
#  'германия': 528,
#  'прошел': 6829,
#  'цикл': 158,
#  'проверок': 188,
#  'выдаче:-': 131,
#  'проверен': 1540,
#  'базам': 1053,
#  'предмет': 1255,
#  'розыска': 331,
#  'угона': 395,
#  'юридически': 3526,
#  'чист-': 144,
#  'тщательно': 390,
#  'проверена': 920,
#  'пройдена': 596,
#  'техническая': 4388,
#  'пунктам-': 282,
#  'реальный': 3825,
#  'пробег': 18873,
#  'соответствует': 857,
#  'показаниям': 136,
#  'панели': 905,
#  'приборов-': 150,
#  'произведена': 1774,
#  'качественная': 530,
#  'химчистка': 940,
#  'предпродажная': 4394,
#  'подготовкаавтополе': 131,
#  '–': 15554,
#  'крупнейший': 466,
#  'регионе': 341,
#  'нас': 7062,
#  'надежна': 551,
#  'выгодна:-': 131,
#  'расширенная': 576,
#  'гарантия': 12331,
#  '24': 1198,
#  'месяцев-': 290,
#  'дополнительный': 827,
#  'помощи': 7409,
#  'дороге': 724,
#  '24/7-': 132,
#  'скидки': 2556,
#  'trade-in-': 461,
#  'доступные': 265,
#  'программы': 2428,
#  'кредитованиядополнительные': 131,
#  'преимущества:-': 145,
#  'консультация': 144,
#  'online': 494,
#  'удобном': 305,
#  'мессенджере-': 131,
#  'быстрое': 273,
#  'оформление': 6351,
#  'кредита': 10838,
#  '2м': 149,
#  'документам': 4341,
#  '(паспорт': 476,
#  '+': 7063,
#  'водительское': 2308,
#  'удостоверение)': 205,
#  'обязательно-': 135,
#  'приобретение': 2968,
#  'полисов': 353,
#  'осаго': 4509,
#  'ведущих': 568,
#  'страховых': 966,
#  'компаний-': 186,
#  'качественный': 536,
#  'детейлинг': 605,
#  'устранением': 148,
#  'малейших': 212,
#  'косметических': 307,
#  'дефектовоставьте': 131,
#  'заявку': 584,
#  'менеджеры': 269,
#  'подготовят': 193,
#  'индивидуальное': 394,
#  'предложение': 3718,
#  'покупке': 14742,
#  'данного': 2580,
#  'автомобилякомплектация': 208,
#  '«520d»:•': 7,
#  'передний': 10323,
#  'задний•': 3232,
#  'кондиционер•': 2547,
#  'климат-контроль•': 615,
#  'водителя': 13339,
#  'пассажира•': 8864,
#  'кожаная': 3554,
#  'обивка': 9300,
#  'новоговсе': 4,
#  'глянцевые': 62,
#  'вставки': 716,
#  'салонеа': 2,
#  'мониторы': 270,
#  'защитной': 573,
#  'пленкевесь': 1,
#  'клеился': 2,
#  'разбора': 26,
#  'защищено': 18,
#  'даже': 2812,
#  'лобовое': 3413,
#  'стеклосамая': 1,
#  'полная': 6303,
#  'комплектация': 14337,
#  'individualцвет': 1,
#  '“чистый': 1,
#  'металл»': 3,
#  'редкийникаких': 1,
#  'недочетов': 146,
#  'нетавто': 19,
#  'мыли': 17,
#  'детейлинг-мойкедтп': 1,
#  'былообмен': 2,
#  'предлагатьразумный': 2,
#  'уместен': 2961,
#  'оригинал': 13962,
#  '(полный': 74,
#  'к-т': 38,
#  'ключей': 7334,
#  'документов)-': 2,
#  'фактический': 92,
#  'владелец-': 298,
#  'дилера-': 613,
#  'регистрация': 493,
#  '30012020г': 1,
#  '(гарантия': 62,
#  '012022г)-': 1,
#  'отличное': 5764,
#  'внешнее': 1256,
#  'техническое': 5244,
#  'состояние-': 224,
#  'весь': 3645,
#  'краске': 5192,
#  '(без': 1641,
#  'дтп)-': 2,
#  'передняя': 1678,
#  'бронепленке-': 11,
#  'охранный': 553,
#  'комплекс-': 8,
#  'оригинальное': 600,
#  'прицепное': 81,
#  'устройствокомплектация': 1,
#  'xdrive30d': 43,
#  'm': 2088,
#  'sport:-': 5,
#  'оснащение': 249,
#  'тормозной': 959,
#  'системой': 1436,
#  'экспорт-': 1,
#  'адаптивная': 557,
#  'подвеска-': 76,
#  '20"': 192,
#  'колс': 22,
#  'дm': 6,
#  'сдвсп699': 6,
#  'бесшн-': 1,
#  'колеса-': 164,
#  'спортивные': 1368,
#  'тормоза': 1871,
#  'm-': 22,
#  'спортивная': 609,
#  'акпп-': 68,
#  'индикация': 382,
#  'шинах-': 135,
#  'комфортный': 2128,
#  'доступ-': 260,
#  'спортивный': 887,
#  'остекление': 635,
#  'улучшенной': 111,
#  'звукоизоляцией-': 2,
#  'velours-': 1,
#  'внутр/нарзеркс': 168,
#  'затемнением-': 35,
#  'внутрзеркало': 135,
#  'автоматичзатемнением-': 2,
#  'элрегположения': 105,
#  'функцпамяти-': 3,
#  'сиденье-': 13,
#  'обогрсиденводителя/передпасс-': 5,
#  'сопровождающее': 198,
#  'освещение': 1128,
#  'салона-': 277,
#  'кондиционирования-': 7,
#  'светодиодная': 903,
#  'фара-': 9,
#  'led': 1497,
#  'fog': 241,
#  'lights-': 2,
#  'автоматическое': 717,
#  'включение': 825,
#  'дальнего': 1321,
#  'света-': 560,
#  'парковки-': 216,
#  'professional-': 20,
#  'дисплей': 1238,
#  'стекле-': 18,
#  'harman/kardon': 367,
#  'объемного': 412,
#  'звучания-': 8,
#  'телефония': 261,
#  'беспроводной': 442,
#  'зарядкой-': 3,
#  'кожаное': 527,
#  'рулевое': 6174,
#  'колесо': 4944,
#  'm-стиле-': 2,
#  'аэродинамический': 739,
#  'technic-': 5,
#  'shadow-line': 246,
#  'зеркальным': 379,
#  'блеском-': 7,
#  'потолок': 1868,
#  'антрацит-': 13,
#  'connected': 428,
#  'paket-': 2,
#  'аккумулятор': 2216,
#  'agm': 387,
#  '90': 772,
#  ...}

# %%
# сделаем два списка: положительные и отрицательные слова
good_words = ['комплект', 'официального', 'салон', 'птс', 'отличном', 'выгода', 'гарантия',
             'комплексную', 'оригинал', 'гарантию', 'официальный', 'подарок', 'гарантии',
              'новая', 'сертифицированными', '✅', 'предпродажную', 'новые', 'favorit',
              'отличное', 'надежный', 'официальным', 'отличный', 'ремонтировалась', 'хорошем']
bad_words = ['дтп', 'срочный', 'трейд-ин', 'ремонтов', 'ремонта', 'капремонта',
             'ремонтных', 'дтпвсе', 'авария', 'аварии']

# заполним поле description цифровыми данными
full_df['description'] = full_df['description'].apply(lambda x: count_words(x, good_words, bad_words))

# %% [markdown]
# ### Сохраним подготовленные для МЛ данные в файл preproc.csv

# %%
full_df.to_csv('preproc.csv', index=False)
